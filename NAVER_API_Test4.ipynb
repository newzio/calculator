# %% [markdown]
# <a href="https://colab.research.google.com/github/newzio/calculator/blob/master/NAVER_API_Test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "PJLO2hgyKMm9JP66b8kF"
client_secret = "koUYD4psxk"
encText = urllib.parse.quote(input("검색 질의 : "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title","Link","Desc"))

for start_index in range(start, end, display):
  url = "https://openapi.naver.com/v1/search/webkr?query=" + encText + "&display=" + str(display) + "&start=" + str(start_index)
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        desc = re.sub(remove_tag,'',items[item_index]['description'])
        web_df.loc[idx] = [title, link, desc]
        idx += 1
  else:
      print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의 : 유지호
#                                      Title  ...                                               Desc
# 0                               유지호 - 나무위키  ...  독립운동가에 대한 내용은 유지호(독립운동가) 문서를 참고하십시오. SBS의 드라마 ...
# 1                             유지호 - 리그베다위키  ...  유지호 최종 변경일자:2014-09-21 02:31:51기여자 목록 보기 다섯 손가...
# 2     유지호 (ssy05468) - Profile | Pinterest  ...  See what 유지호 (ssy05468) has discovered on Pint...
# 3                               유지호 – KASA  ...  유지호/Jiho You 에이디(AD) Careers 전)샘스튜디오(Sam Recor...
# 4                           리스트 보기 - 다음 영화  ...  유지호 Chi-Ho Lau, 劉志豪 직업 배우, 스턴트맨, 무술감독 성별 남성 인물...
# ..                                     ...  ...                                                ...
# 195                                 봄밤 유지호  ...  유지호 때문에 힐링받았던 봄밤 따뜻하고 다정한 말투, 사랑스러워 죽겠다는 눈빛 짠내...
# 196  ‘봄밤’ 이를 들은 유지호는 자리를 피했다... - 제주교통복지신문  ...  핫이슈 홈 핫이슈 ‘봄밤’ 이를 들은 유지호는 자리를 피했다... 온라인 뉴스팀 *...
# ...

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "PJLO2hgyKMm9JP66b8kF"
client_secret = "koUYD4psxk"
encText = urllib.parse.quote(input("검색 질의 : "))

idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title","Link","Desc"))

for start_index in range(start, end, display):
  url = "https://openapi.naver.com/v1/search/kin?query=" + encText + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        desc = re.sub(remove_tag,'',items[item_index]['description'])
        kin_df.loc[idx] = [title, link, desc]
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의 : 유지호
#                               Title  ...                                               Desc
# 0                   대전명석고 유도에이스 유지호  ...  대전명석고 유지호는 -66kg 에이스로 특출난 외모로 여자들에게 인기도많고 공부또한...
# 1     논문작성 중 참고자료 검색(유지호, 예멘통일이...   ...  논문 작성중에 이 자료를 찾는데 유지호, 예멘통일이... 논문작성 중 참고자료 검색...
# 2                   유지호 이름풀이 부탁드립니다  ...  ... (수리력대발복운) 유 지 호 柳:9획 志:7획(뜻 지) 昊:8획(하늘 호) ...
# 3    다섯손가락에서 홍다미랑 유지호랑 제1화때 쳤던곡...   ...  제 1화에서 홍다미랑 유지호가 어릴때 쳤던곡 잇잖아요 그럼 계이름 좀 알려주세요.....
# 4          다섯손가락 23회 유인하가 유지호앞에...   ...  ... ^^ heart and soul(홍다미,유인하) 쇼팽 - 에튀드 나비 쇼팽 ...
# ..                              ...  ...                                                ...
# 752            빅스 입덕한거같아여ㅕ...살려줘ㅠㅠㅠ  ...  ... 남주 유지호 역을 맡고있습니다! (다섯번째) 빅스와 젤리피쉬 엔터테인먼트 유...
# 753            소설 이름이랑 남주랑 여주 좀요 ㅠㅠ  ...  ... 솔,이정재,장신비,다도중,조은남,정한중,박훈남,정면아,다경진,하정진,유지호,...
# 754                     무한도전 유재석 질문  ...  ... 이름 유재석(劉在錫) 출생 1972년 8월 14일, 서울특별시 신체 175~...
# ...

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "PJLO2hgyKMm9JP66b8kF"
client_secret = "koUYD4psxk"
encText = urllib.parse.quote(input("검색 질의 : "))

idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title","Link","Desc"))

for start_index in range(start, end, display):
  url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        desc = re.sub(remove_tag,'',items[item_index]['description'])
        kin_df.loc[idx] = [title, link, desc]
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의 : 유지호
#                                              Title  ...                                               Desc
# 0                             육아일기 217일 유지호 이유식 전쟁  ...  인생 첫 백화점 유모차에 거부반응이 없는걸 알게 됐으니 쇼핑도 가능해졌다...ㅎㅎ ...
# 1    유지호, &lt;최초의 여자들&gt;, 나는 누구인가? 정체성 탈피의 경험...   ...  최초의 여자들 저자 유지호 출판 스크로파 발매 2020.10.13. ㅡ 최근에 미주...
# 2            봄밤 7회/8회 : 아, 왜 거기 그렇게 서 있는 거니? 유지호ㅠㅠ  ...  그리고, 이토록 몰입하여 대사를 치는 정해인과 한지민은 그냥 그 자체로 '유지호'고...
# 3                      봄밤 촬영지 우리약국 얼큰칼국수 유지호집 이정인집  ...  우리 유지호 약사님이 주로 활동하시는 우리약국은 생각보다 내부가 넓었어요. 그리고 ...
# 4             HDS-KIDA Pro-am - Pre-finalist (유지호)  ...  Previous image Next image &lt;유지호&gt; ◈ 경력 201...
# ..                                             ...  ...                                                ...
# 995                         후원업체 패션그룹 형지 최병오 회장 면담  ...  우린 2층 회의실에 약 30분 정도 먼저 모여 유지호 본부장님과 인사를 하고, 조금...
# 996        무등산 단풍을 담아보았어요...2011년10월29일 무등산 정상...   ...  유지호 기자 &lt;hwaone joongang.co.kr=&quot;JOONGAN...
# ...

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "PJLO2hgyKMm9JP66b8kF"
client_secret = "koUYD4psxk"
encText = urllib.parse.quote(input("검색 질의 : "))

idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title","Link","Desc"))

for start_index in range(start, end, display):
  url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['link']
        desc = re.sub(remove_tag,'',items[item_index]['description'])
        kin_df.loc[idx] = [title, link, desc]
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "PJLO2hgyKMm9JP66b8kF"
client_secret = "koUYD4psxk"
encText = urllib.parse.quote(input("검색 질의 : "))

idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title","Link","Image"))

for start_index in range(start, end, display):
  url = "https://openapi.naver.com/v1/search/book?query=" + encText + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag,'',items[item_index]['title'])
        link = items[item_index]['image']
        desc = re.sub(remove_tag,'',items[item_index]['image'])
        kin_df.loc[idx] = [title, link, desc]
        idx += 1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의 : AWS
#                                                  Title  ...                                              Image
# 0    스프링 부트와 AWS로 혼자 구현하는 웹 서비스 (인텔리제이, JPA, JUnit ...  ...  https://bookthumb-phinf.pstatic.net/cover/158/...
# 1                                 따라하며 배우는 AWS 네트워크 입문  ...  https://bookthumb-phinf.pstatic.net/cover/168/...
# 2    아마존 웹 서비스(AWS)로 시작하는 데브옵스(AWS DevOps Discovery...  ...  https://bookthumb-phinf.pstatic.net/cover/163/...
# 3    14가지 AWS 구축 패턴(배워서 바로 쓰는) (서버리스에서 마이크로서비스와 AI까...  ...  https://bookthumb-phinf.pstatic.net/cover/162/...
# 4                AWS 공인 솔루션스 아키텍트 스터디 가이드(2판) (어소시에이트)  ...  https://bookthumb-phinf.pstatic.net/cover/163/...
# ..                                                 ...  ...                                                ...
# 920                                        용접 구조설계와 시공  ...
# 921                                            교량 용접기준  ...
# 922      Kap of Nurses Towards Emergency Contraception  ...
# ...
